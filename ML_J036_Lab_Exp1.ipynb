# %%
#Akash Patil
#J036

#Q1] Categorical: HospT, Treat, Outcome, Gender
#Q2] Quantitate: Time, Age, AcuteT
#Q3] No difference=602, Opposite Sex= 434, Same Sex=164
#Q4] It is a column/list containing age of 44 Actors, mean age is 44.98, median age(centre) is 43.35 and standard deviation(spread) is 9.75. Outlier is an actor with age 76.
a<- read.csv(file.choose())
summary(a$Age)
plot(a$Age)
#Q5] a. 44
#        b. mean=44.98
#        c. Min.    1st Qu.     Median     Mean    3rd Qu.    Max. 
#           29.00    38.00      43.50      44.98    50.25     76.00  
#Q6] a. Min.    1st Qu.     Median     Mean    3rd Qu.    Max. 
#       29.00    38.00       43.50     44.98    50.25     76.00  
#Q7] standard dev:
#        Class1 = 1.568929
#        Class2 = 4
#        Class3 = 2.631174
a<- read.csv(file.choose())
sd(a$Class.I)
sd(a$Class.II)
sd(a$Class.III)
#Q8] Class1 has a mean of approx. 5. 
#    In class2 most observations are spread far from mean(distant) hence the standard deviation is higher. 
#    In Class3 there is a mix of both close and far from main observations. 
#    Therefore Class1 has smallest Standard Deviation followed by Class3 and Class2
# Out:
# Warning message in file(file, "rt"):
# “cannot open file '<a8>q<a7><a4>U': No such file or directory”
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.csv(file.choose())
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. file(file, "rt")
